# %% [markdown]
# # Grid Dispatch and Storage
#
# Placeholder notebook for advanced dispatch, storage, and renewable variability analysis.

# %%
from pathlib import Path
import csv

path = Path('../data/synthetic/hourly_load_and_renewables.csv')
with path.open() as handle:
    rows = list(csv.DictReader(handle))
rows[:3]
